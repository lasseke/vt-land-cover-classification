# %% [markdown]
# # Visualize final VT modelling data

# %%
import pandas as pd
import matplotlib.pyplot as plt
from src.visualization import vtdata as vtplt

# %%
### Read full data
data_path = "../data/interim/vtdata.pkl"
data_df = pd.read_pickle(
    f"{data_path}"
)

# %% [markdown]
# ## 1. Plot class distribution

# %%
data_df['vt']
# Out:
# 0         8b
# 1        2ef
# 2        2ef
# 3        2ef
# 4         6a
#         ...
# 22168     2b
# 22169     8a
# 22170     4c
# 22171    11b
# 22172     7b
# Name: vt, Length: 22173, dtype: category
# Categories (31, object): ['10ab', '10c', '11b', '12b', ..., '8cd', '9ad', '9bc', '9e']

# %%
# Count number of occurrences
vt_freq_series = data_df['vt'].value_counts()
vt_freq_series
# Out:
# 2ef     3004
# 9bc     2334
# 6a      1924
# 2c      1465
# 7b      1441
# 1ab     1425
# 4b      1222
# 8cd     1096
# 9ad      931
# 4a       894
# 4c       703
# 12b      680
# 3ab      617
# 12c      511
# 7c       487
# 7a       419
# 11b      391
# 8b       353
# 6b       348
# 2g       302
# 8a       259
# 1c       250
# 10ab     248
# 2d       167
# 2a       137
# 2b       126
# 10c      122
# 4e        96
# 5ab       95
# 4g        79
# 9e        47
# Name: vt, dtype: int64

# %%
vtplt.barplot_class_frequency(
    vt_freq_series=vt_freq_series,
    figsize=(16/2.54, 20/2.54),
    save_as='vt_class_frequency.png'
)

# %%
data_df.columns
# Out:
# Index(['x', 'y', 'vt', 'plot_id', 'B11_median_comp_Sent2',
#        'B12_median_comp_Sent2', 'B1_median_comp_Sent2', 'B2_median_comp_Sent2',
#        'B3_median_comp_Sent2', 'B4_median_comp_Sent2', 'B5_median_comp_Sent2',
#        'B6_median_comp_Sent2', 'B7_median_comp_Sent2', 'B8A_median_comp_Sent2',
#        'B8_median_comp_Sent2', 'B9_median_comp_Sent2',
#        'EVI_greenest_pixel_Sent2', 'EVI_median_comp_Sent2',
#        'GNDVI_greenest_pixel_Sent2', 'GNDVI_median_comp_Sent2',
#        'NDMI_greenest_pixel_Sent2', 'NDMI_median_comp_Sent2',
#        'NDVI_greenest_pixel_Sent2', 'NDVI_median_comp_Sent2',
#        'SAVI_greenest_pixel_Sent2', 'SAVI_median_comp_Sent2',
#        'B1_median_comp_Lands7', 'B2_median_comp_Lands7',
#        'B3_median_comp_Lands7', 'B4_median_comp_Lands7',
#        'B5_median_comp_Lands7', 'B6_median_comp_Lands7',
#        'B7_median_comp_Lands7', 'EVI_greenest_pixel_Lands7',
#        'EVI_median_comp_Lands7', 'GNDVI_greenest_pixel_Lands7',
# ...
